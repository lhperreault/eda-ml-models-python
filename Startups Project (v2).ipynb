# %% [markdown]
# # Startups Project
# ## IN015 - Data Mining
# - Professor: Pablo Hernandez
# - Students:
#     - José Pablo del Moral García
#     - Marc Esteller Sánchez
#     - Òscar Grau Gesa
#     - Clara Jiménez i Seoane
#     - Luke Harrison Perreault

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.stats as stats

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
import warnings

# To ignore all warnings
warnings.filterwarnings("ignore")

# %%
# Setup Libraries
# %matplotlib inline

# %%
import os

# Get the current working directory
current_directory = os.getcwd()

# Print or use the current working directory as needed
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: c:\Users\lukep\Documents\Salle\Business\Second Year\2nd Semester\Data Mining\Projects\Final Project

# %% [markdown]
# ## Get the Data

# %%
df = pd.read_csv('../datasets/startup_traction.csv')
df.shape
# Out:
# (700, 30)

# %%
df.sample(5)
# Out:
#      Unnamed: 0                       name      country       city
# 205         327   REMEDY BIOLOGICS LIMITED      IRELAND  ASHBOURNE  \
# 222        1590            AXO SCIENCE SAS       FRANCE       LYON
# 287         534  LEYDENJAR TECHNOLOGIES BV  NETHERLANDS     LEIDEN
# 316        1006               AUTOAID GMBH      GERMANY     BERLIN
# 546         307                   WIMAO OY      FINLAND  KONNUNSUO
#
#                                 web        PIC  stage_order stage_name
# 205  http://www.remedybiologics.com  909408951            1  INCEPTION  \
# 222                             NaN  958174440            1  INCEPTION
# 287       http://www.leyden-jar.com  913684226            1  INCEPTION
# 316           http://www.autoaid.de  929887688            1  INCEPTION
# 546             http://www.wimao.fi  908461843            1  INCEPTION
#
#      tweet_count  tweet_length  ...  reply_ratio  reply_rate  like_count
# 205          5.0    192.600000  ...     0.200000    0.003096        39.0  \
# 222          NaN           NaN  ...          NaN         NaN         NaN
# 287         15.0    214.133333  ...     0.266667    0.014286        55.0
# 316          NaN           NaN  ...          NaN         NaN         NaN
# 546          NaN           NaN  ...          NaN         NaN         NaN
#
#      like_rate  like_ratio  quote_count  quote_rate  quote_ratio
# 205   0.120743    7.800000         39.0    0.120743     7.800000  \
# 222        NaN         NaN          NaN         NaN          NaN
# 287   0.196429    3.666667         55.0    0.196429     3.666667
# 316        NaN         NaN          NaN         NaN          NaN
# 546        NaN         NaN          NaN         NaN          NaN
#
#      engagement_ratio  stage_success
# 205         10.800000              0
# 222               NaN              0
# 287          5.333333              1
# 316               NaN              0
# 546               NaN              0
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               700 non-null    int64
#  1   name                     700 non-null    object
#  2   country                  700 non-null    object
#  3   city                     700 non-null    object
#  4   web                      649 non-null    object
#  5   PIC                      700 non-null    int64
#  6   stage_order              700 non-null    int64
#  7   stage_name               700 non-null    object
#  8   tweet_count              309 non-null    float64
#  9   tweet_length             309 non-null    float64
#  10  tweet_rate               309 non-null    float64
#  11  original_ratio           307 non-null    float64
#  12  retweeted_ratio          289 non-null    float64
#  13  replied_to_ratio         243 non-null    float64
#  14  quoted_ratio             259 non-null    float64
#  15  quoted_replied_to_ratio  18 non-null     float64
#  16  retweet_count            309 non-null    float64
#  17  retweet_ratio            309 non-null    float64
#  18  retweet_rate             309 non-null    float64
#  19  reply_count              309 non-null    float64
#  20  reply_ratio              309 non-null    float64
#  21  reply_rate               309 non-null    float64
#  22  like_count               309 non-null    float64
#  23  like_rate                309 non-null    float64
#  24  like_ratio               309 non-null    float64
#  25  quote_count              309 non-null    float64
#  26  quote_rate               309 non-null    float64
#  27  quote_ratio              309 non-null    float64
#  28  engagement_ratio         309 non-null    float64
#  29  stage_success            700 non-null    int64
# dtypes: float64(21), int64(4), object(5)
# memory usage: 164.2+ KB

# %% [markdown]
# ## Clean the data

# %% [markdown]
# As we can see with df.info() there are many nulls, we are going to analyze them. Since the ratios are calculated through the variables count, we are going to see more in deep just the count variables and see how can we fix those nulls.

# %%
null_web = df[df['web'].isnull()]
null_web
# Out:
#      Unnamed: 0                                               name
# 0           669                                      N.P.T. S.R.L.  \
# 9          1109                                            CASCADE
# 10          105                                     SAGANATURA EHF
# 20          441                                       MIRMEX MOTOR
# 30          344                                         JPU.IO LTD
# 41           90                               GREENVOLT NANOMA EHF
# 87          350                                      BOTSANDUS LTD
# 89         1183                        DIANIA TECHNOLOGIES LIMITED
# 91         1242                                    ADA HEALTH GMBH
# 95          451                                        NEWPACE LTD
# 100         950                         COGNE MACCHINE TESSILI SPA
# 109         766                  SAFE LOAD TESTING TECHNOLOGIES SL
# 110         392                                      ANOTHER BRAIN
# 114         671                                  DT EQUIPMENT EHF.
# 120         604                                          CLIIN APS
# 123         627                                     SPECTRAPPLY SL
# 130         321                                          CURIO EHF
# 144        1452                                      VISUM LIMITED
# 160         104                         BLUE CODE INTERNATIONAL AG
# 162         998                                     TAGSONOMY S.L.
# 171         702                             SEALANTIUM MEDICAL LTD
# 192         635                                     ILYA PHARMA AB
# 197         691                                           FWE GMBH
# 202        1382                       SETENTA E TRES MIL E CEM LDA
# 222        1590                                    AXO SCIENCE SAS
# 237        1446                                      NANOVATION-GS
# 299          59  SORANUS ARGE VE DANISMANLIK HIZMETLERI SANAYI ...
# 339         281                           SWISS VAULT SYSTEMS GMBH
# 344         951                                        NUCLEIX LTD
# 356         859                            HWS CONCRETE TOWERS, SL
# 360        1219                                         HYDROKEMOS
# 380        1537                          AQUILA BIOSCIENCE LIMITED
# 384        1713                                         SAP FRANCE
# 388         765  ADVANCED & FUNCTIONAL TECHNOLOGIES FOR BIOCOMP...
# 411        1520                                              MITIS
# 419        1278                              BLOOM TECHNOLOGIES NV
# 427          33                                   DEEP HEALTH LTD.
# 447         949                                          LADIMO OY
# 451         821                                        ADDIFAB APS
# 490         121                                     THE HABLAB APS
# 530        1602                                 BLU ELECTRONIC SRL
# 533         286                                          NOMOKO AG
# 547         770                                       BLUBRAKE SRL
# 567        1598                                   NATAC BIOTECH SL
# 583        1634                                       XMOS LIMITED
# 585         816                        SEAWEED ENERGY SOLUTIONS AS
# 605         972  LA. ME. P. DI CAMPOLUCCI ERINO & C.SOCIETA IN ...
# 610         774                              AMAPEX TRADING, S.L.U
# 648         675                                 AURORA SEAFOOD EHF
# 686         600                      PRIVATE ENTERPRISE «DOMINION»
# 698         559                         MILLOR ENERGY SOLUTIONS SL
#
#             country                    city  web        PIC  stage_order
# 0             ITALY          VALSAMOGGIA BO  NaN  917744355            1  \
# 9            FRANCE                 CLAMART  NaN  934348718            1
# 10          ICELAND           HAFNARFJORDUR  NaN  902859414            1
# 20          BELGIUM                  CHIMAY  NaN  911270381            1
# 30           ISRAEL            PETACH TIKVA  NaN  910101822            1
# 41          ICELAND               REYKJAVIK  NaN  901250378            1
# 87   UNITED KINGDOM              BOURNE END  NaN  910321333            1
# 89          IRELAND                  GALWAY  NaN  934968451            1
# 91          GERMANY                  BERLIN  NaN  935923028            1
# 95           ISRAEL                CAESAREA  NaN  911414038            1
# 100           ITALY                IMOLA BO  NaN  927163637            1
# 109           SPAIN                 PATERNA  NaN  920616622            1
# 110          FRANCE                   PARIS  NaN  910683725            1
# 114         ICELAND               REYKJAVÍK  NaN  917752115            1
# 120         DENMARK                  SØBORG  NaN  916564932            1
# 123           SPAIN                  OVIEDO  NaN  916952835            1
# 130         ICELAND           HAFNARFJORDUR  NaN  909312145            1
# 144         IRELAND                LISTOWEL  NaN  942630578            1
# 160     SWITZERLAND               LACHEN SZ  NaN  902734284            1
# 162           SPAIN                  MADRID  NaN  929769348            1
# 171          ISRAEL            ROSH HA'AYIN  NaN  918407156            1
# 192          SWEDEN                 UPPSALA  NaN  917075249            1
# 197         GERMANY            MARKTREDWITZ  NaN  918243711            1
# 202        PORTUGAL    RIO DE MOINHOS BORBA  NaN  938637670            1
# 222          FRANCE                    LYON  NaN  958174440            1
# 237          ISRAEL             RAMAY ISHAI  NaN  941974567            1
# 299          TURKEY                   IZMIR  NaN  899932536            1
# 339     SWITZERLAND                   BASEL  NaN  907603587            1
# 344          ISRAEL                 REHOVOT  NaN  927191379            1
# 356           SPAIN  SAN SEBASTIAN GIPUZKOA  NaN  924273231            1
# 360       BARCELONA                 TORELLÓ  NaN  935419404            1
# 380         IRELAND        MOYCULLEN GALWAY  NaN  952728763            1
# 384          FRANCE        LEVALLOIS PERRET  NaN  997753932            1
# 388           SPAIN                 PATERNA  NaN  920614682            1
# 411         BELGIUM                  HANNUT  NaN  952301478            1
# 419         BELGIUM              DIEPENBEEK  NaN  936645581            1
# 427          ISRAEL                RECHOVOT  NaN  898794435            1
# 447         FINLAND                   ESPOO  NaN  927161115            1
# 451         DENMARK                JYLLINGE  NaN  923088764            1
# 490         DENMARK              COPENHAGEN  NaN  903856768            1
# 530           ITALY                   DESIO  NaN  960132482            1
# 533     SWITZERLAND                  ZURICH  NaN  907650632            1
# 547           ITALY                  MILANO  NaN  920740200            1
# 567           SPAIN                  MADRID  NaN  959108453            1
# 583  UNITED KINGDOM                  LONDON  NaN  968930285            1
# 585          NORWAY               TRONDHEIM  NaN  922917947            1
# 605           ITALY                    ROMA  NaN  927697234            1
# 610           SPAIN               BARCELONA  NaN  920814987            1
# 648         ICELAND               GARDABAER  NaN  917817590            1
# 686         UKRAINE                    KYIV  NaN  916541167            1
# 698           SPAIN                TERRASSA  NaN  914997509            1
#
#     stage_name  tweet_count  tweet_length  ...  reply_ratio  reply_rate
# 0    INCEPTION          NaN           NaN  ...          NaN         NaN  \
# 9    INCEPTION          NaN           NaN  ...          NaN         NaN
# 10   INCEPTION          NaN           NaN  ...          NaN         NaN
# 20   INCEPTION          NaN           NaN  ...          NaN         NaN
# 30   INCEPTION          NaN           NaN  ...          NaN         NaN
# 41   INCEPTION          NaN           NaN  ...          NaN         NaN
# 87   INCEPTION          NaN           NaN  ...          NaN         NaN
# 89   INCEPTION          NaN           NaN  ...          NaN         NaN
# 91   INCEPTION          NaN           NaN  ...          NaN         NaN
# 95   INCEPTION          NaN           NaN  ...          NaN         NaN
# 100  INCEPTION          NaN           NaN  ...          NaN         NaN
# 109  INCEPTION          NaN           NaN  ...          NaN         NaN
# 110  INCEPTION          NaN           NaN  ...          NaN         NaN
# 114  INCEPTION          NaN           NaN  ...          NaN         NaN
# 120  INCEPTION          NaN           NaN  ...          NaN         NaN
# 123  INCEPTION          NaN           NaN  ...          NaN         NaN
# 130  INCEPTION          NaN           NaN  ...          NaN         NaN
# 144  INCEPTION          NaN           NaN  ...          NaN         NaN
# 160  INCEPTION          NaN           NaN  ...          NaN         NaN
# 162  INCEPTION          NaN           NaN  ...          NaN         NaN
# 171  INCEPTION          NaN           NaN  ...          NaN         NaN
# 192  INCEPTION          NaN           NaN  ...          NaN         NaN
# 197  INCEPTION          NaN           NaN  ...          NaN         NaN
# 202  INCEPTION         44.0    172.181818  ...     0.045455    0.002183
# 222  INCEPTION          NaN           NaN  ...          NaN         NaN
# 237  INCEPTION          NaN           NaN  ...          NaN         NaN
# 299  INCEPTION          NaN           NaN  ...          NaN         NaN
# 339  INCEPTION          NaN           NaN  ...          NaN         NaN
# 344  INCEPTION          NaN           NaN  ...          NaN         NaN
# 356  INCEPTION          NaN           NaN  ...          NaN         NaN
# 360  INCEPTION          NaN           NaN  ...          NaN         NaN
# 380  INCEPTION          NaN           NaN  ...          NaN         NaN
# 384  INCEPTION          NaN           NaN  ...          NaN         NaN
# 388  INCEPTION        585.0    194.246154  ...     0.070085    0.030303
# 411  INCEPTION          NaN           NaN  ...          NaN         NaN
# 419  INCEPTION          NaN           NaN  ...          NaN         NaN
# 427  INCEPTION          NaN           NaN  ...          NaN         NaN
# 447  INCEPTION          NaN           NaN  ...          NaN         NaN
# 451  INCEPTION          NaN           NaN  ...          NaN         NaN
# 490  INCEPTION          NaN           NaN  ...          NaN         NaN
# 530  INCEPTION          NaN           NaN  ...          NaN         NaN
# 533  INCEPTION          NaN           NaN  ...          NaN         NaN
# 547  INCEPTION          NaN           NaN  ...          NaN         NaN
# 567  INCEPTION          NaN           NaN  ...          NaN         NaN
# 583  INCEPTION          NaN           NaN  ...          NaN         NaN
# 585  INCEPTION          NaN           NaN  ...          NaN         NaN
# 605  INCEPTION          NaN           NaN  ...          NaN         NaN
# 610  INCEPTION          NaN           NaN  ...          NaN         NaN
# 648  INCEPTION          NaN           NaN  ...          NaN         NaN
# 686  INCEPTION          NaN           NaN  ...          NaN         NaN
# 698  INCEPTION          NaN           NaN  ...          NaN         NaN
#
#      like_count  like_rate  like_ratio  quote_count  quote_rate  quote_ratio
# 0           NaN        NaN         NaN          NaN         NaN          NaN  \
# 9           NaN        NaN         NaN          NaN         NaN          NaN
# 10          NaN        NaN         NaN          NaN         NaN          NaN
# 20          NaN        NaN         NaN          NaN         NaN          NaN
# 30          NaN        NaN         NaN          NaN         NaN          NaN
# 41          NaN        NaN         NaN          NaN         NaN          NaN
# 87          NaN        NaN         NaN          NaN         NaN          NaN
# 89          NaN        NaN         NaN          NaN         NaN          NaN
# 91          NaN        NaN         NaN          NaN         NaN          NaN
# 95          NaN        NaN         NaN          NaN         NaN          NaN
# 100         NaN        NaN         NaN          NaN         NaN          NaN
# 109         NaN        NaN         NaN          NaN         NaN          NaN
# 110         NaN        NaN         NaN          NaN         NaN          NaN
# 114         NaN        NaN         NaN          NaN         NaN          NaN
# 120         NaN        NaN         NaN          NaN         NaN          NaN
# 123         NaN        NaN         NaN          NaN         NaN          NaN
# 130         NaN        NaN         NaN          NaN         NaN          NaN
# 144         NaN        NaN         NaN          NaN         NaN          NaN
# 160         NaN        NaN         NaN          NaN         NaN          NaN
# 162         NaN        NaN         NaN          NaN         NaN          NaN
# 171         NaN        NaN         NaN          NaN         NaN          NaN
# 192         NaN        NaN         NaN          NaN         NaN          NaN
# 197         NaN        NaN         NaN          NaN         NaN          NaN
# 202       104.0   0.113537    2.363636        104.0    0.113537     2.363636
# 222         NaN        NaN         NaN          NaN         NaN          NaN
# 237         NaN        NaN         NaN          NaN         NaN          NaN
# 299         NaN        NaN         NaN          NaN         NaN          NaN
# 339         NaN        NaN         NaN          NaN         NaN          NaN
# 344         NaN        NaN         NaN          NaN         NaN          NaN
# 356         NaN        NaN         NaN          NaN         NaN          NaN
# 360         NaN        NaN         NaN          NaN         NaN          NaN
# 380         NaN        NaN         NaN          NaN         NaN          NaN
# 384         NaN        NaN         NaN          NaN         NaN          NaN
# 388      1176.0   0.869180    2.010256       1176.0    0.869180     2.010256
# 411         NaN        NaN         NaN          NaN         NaN          NaN
# 419         NaN        NaN         NaN          NaN         NaN          NaN
# 427         NaN        NaN         NaN          NaN         NaN          NaN
# 447         NaN        NaN         NaN          NaN         NaN          NaN
# 451         NaN        NaN         NaN          NaN         NaN          NaN
# 490         NaN        NaN         NaN          NaN         NaN          NaN
# 530         NaN        NaN         NaN          NaN         NaN          NaN
# 533         NaN        NaN         NaN          NaN         NaN          NaN
# 547         NaN        NaN         NaN          NaN         NaN          NaN
# 567         NaN        NaN         NaN          NaN         NaN          NaN
# 583         NaN        NaN         NaN          NaN         NaN          NaN
# 585         NaN        NaN         NaN          NaN         NaN          NaN
# 605         NaN        NaN         NaN          NaN         NaN          NaN
# 610         NaN        NaN         NaN          NaN         NaN          NaN
# 648         NaN        NaN         NaN          NaN         NaN          NaN
# 686         NaN        NaN         NaN          NaN         NaN          NaN
# 698         NaN        NaN         NaN          NaN         NaN          NaN
#
#      engagement_ratio  stage_success
# 0                 NaN              0
# 9                 NaN              0
# 10                NaN              0
# 20                NaN              0
# 30                NaN              0
# 41                NaN              0
# 87                NaN              0
# 89                NaN              0
# 91                NaN              0
# 95                NaN              0
# 100               NaN              0
# 109               NaN              0
# 110               NaN              0
# 114               NaN              0
# 120               NaN              0
# 123               NaN              0
# 130               NaN              0
# 144               NaN              0
# 160               NaN              0
# 162               NaN              0
# 171               NaN              0
# 192               NaN              1
# 197               NaN              0
# 202          3.659091              0
# 222               NaN              0
# 237               NaN              0
# 299               NaN              0
# 339               NaN              0
# 344               NaN              0
# 356               NaN              0
# 360               NaN              0
# 380               NaN              0
# 384               NaN              0
# 388         24.738462              0
# 411               NaN              0
# 419               NaN              0
# 427               NaN              0
# 447               NaN              0
# 451               NaN              0
# 490               NaN              0
# 530               NaN              0
# 533               NaN              0
# 547               NaN              0
# 567               NaN              0
# 583               NaN              0
# 585               NaN              0
# 605               NaN              0
# 610               NaN              0
# 648               NaN              0
# 686               NaN              0
# 698               NaN              0
#
# [51 rows x 30 columns]

# %%
null_tw_count = df[df['tweet_count'].isnull()]
null_tw_count
# Out:
#      Unnamed: 0                        name      country
# 0           669               N.P.T. S.R.L.        ITALY  \
# 2          1643                GRAPHENEA SA        SPAIN
# 3           331           CROIVALVE LIMITED      IRELAND
# 6           266                 NEOMEDLIGHT       FRANCE
# 7          1704                ROVALMA, S.A        SPAIN
# ..          ...                         ...          ...
# 694         763         CERCARE MEDICAL APS      DENMARK
# 695         835                   SWEGAN AB       SWEDEN
# 696        1216         MILKWAYS HOLDING BV  NETHERLANDS
# 698         559  MILLOR ENERGY SOLUTIONS SL        SPAIN
# 699         684                    IKOI SPA        ITALY
#
#                         city                            web        PIC
# 0             VALSAMOGGIA BO                            NaN  917744355  \
# 2    SAN SEBASTIAN GUIPUZCOA       http://www.graphenea.com  971995582
# 3                     DUBLIN       http://www.croivalve.com  909573463
# 6               VILLEURBANNE     http://www.neomedlight.com  906740675
# 7                   TERRASSA         http://www.rovalma.com  996728545
# ..                       ...                            ...        ...
# 694                 AARHUS C  http://www.cercaremedical.com  920595961
# 695                LINKOPING           http://www.swegan.se  923998527
# 696                   HATTEM        http://www.milkways.com  935402623
# 698                 TERRASSA                            NaN  914997509
# 699                  CASSOLA             http://www.ikoi.it  918087735
#
#      stage_order stage_name  tweet_count  tweet_length  ...  reply_ratio
# 0              1  INCEPTION          NaN           NaN  ...          NaN  \
# 2              1  INCEPTION          NaN           NaN  ...          NaN
# 3              1  INCEPTION          NaN           NaN  ...          NaN
# 6              1  INCEPTION          NaN           NaN  ...          NaN
# 7              1  INCEPTION          NaN           NaN  ...          NaN
# ..           ...        ...          ...           ...  ...          ...
# 694            1  INCEPTION          NaN           NaN  ...          NaN
# 695            1  INCEPTION          NaN           NaN  ...          NaN
# 696            1  INCEPTION          NaN           NaN  ...          NaN
# 698            1  INCEPTION          NaN           NaN  ...          NaN
# 699            1  INCEPTION          NaN           NaN  ...          NaN
#
#      reply_rate  like_count  like_rate  like_ratio  quote_count  quote_rate
# 0           NaN         NaN        NaN         NaN          NaN         NaN  \
# 2           NaN         NaN        NaN         NaN          NaN         NaN
# 3           NaN         NaN        NaN         NaN          NaN         NaN
# 6           NaN         NaN        NaN         NaN          NaN         NaN
# 7           NaN         NaN        NaN         NaN          NaN         NaN
# ..          ...         ...        ...         ...          ...         ...
# 694         NaN         NaN        NaN         NaN          NaN         NaN
# 695         NaN         NaN        NaN         NaN          NaN         NaN
# 696         NaN         NaN        NaN         NaN          NaN         NaN
# 698         NaN         NaN        NaN         NaN          NaN         NaN
# 699         NaN         NaN        NaN         NaN          NaN         NaN
#
#      quote_ratio  engagement_ratio  stage_success
# 0            NaN               NaN              0
# 2            NaN               NaN              0
# 3            NaN               NaN              0
# 6            NaN               NaN              0
# 7            NaN               NaN              0
# ..           ...               ...            ...
# 694          NaN               NaN              0
# 695          NaN               NaN              0
# 696          NaN               NaN              0
# 698          NaN               NaN              0
# 699          NaN               NaN              0
#
# [391 rows x 30 columns]

# %%
null_retw_count = df[df['retweet_count'].isnull()]
null_retw_count
# Out:
#      Unnamed: 0                        name      country
# 0           669               N.P.T. S.R.L.        ITALY  \
# 2          1643                GRAPHENEA SA        SPAIN
# 3           331           CROIVALVE LIMITED      IRELAND
# 6           266                 NEOMEDLIGHT       FRANCE
# 7          1704                ROVALMA, S.A        SPAIN
# ..          ...                         ...          ...
# 694         763         CERCARE MEDICAL APS      DENMARK
# 695         835                   SWEGAN AB       SWEDEN
# 696        1216         MILKWAYS HOLDING BV  NETHERLANDS
# 698         559  MILLOR ENERGY SOLUTIONS SL        SPAIN
# 699         684                    IKOI SPA        ITALY
#
#                         city                            web        PIC
# 0             VALSAMOGGIA BO                            NaN  917744355  \
# 2    SAN SEBASTIAN GUIPUZCOA       http://www.graphenea.com  971995582
# 3                     DUBLIN       http://www.croivalve.com  909573463
# 6               VILLEURBANNE     http://www.neomedlight.com  906740675
# 7                   TERRASSA         http://www.rovalma.com  996728545
# ..                       ...                            ...        ...
# 694                 AARHUS C  http://www.cercaremedical.com  920595961
# 695                LINKOPING           http://www.swegan.se  923998527
# 696                   HATTEM        http://www.milkways.com  935402623
# 698                 TERRASSA                            NaN  914997509
# 699                  CASSOLA             http://www.ikoi.it  918087735
#
#      stage_order stage_name  tweet_count  tweet_length  ...  reply_ratio
# 0              1  INCEPTION          NaN           NaN  ...          NaN  \
# 2              1  INCEPTION          NaN           NaN  ...          NaN
# 3              1  INCEPTION          NaN           NaN  ...          NaN
# 6              1  INCEPTION          NaN           NaN  ...          NaN
# 7              1  INCEPTION          NaN           NaN  ...          NaN
# ..           ...        ...          ...           ...  ...          ...
# 694            1  INCEPTION          NaN           NaN  ...          NaN
# 695            1  INCEPTION          NaN           NaN  ...          NaN
# 696            1  INCEPTION          NaN           NaN  ...          NaN
# 698            1  INCEPTION          NaN           NaN  ...          NaN
# 699            1  INCEPTION          NaN           NaN  ...          NaN
#
#      reply_rate  like_count  like_rate  like_ratio  quote_count  quote_rate
# 0           NaN         NaN        NaN         NaN          NaN         NaN  \
# 2           NaN         NaN        NaN         NaN          NaN         NaN
# 3           NaN         NaN        NaN         NaN          NaN         NaN
# 6           NaN         NaN        NaN         NaN          NaN         NaN
# 7           NaN         NaN        NaN         NaN          NaN         NaN
# ..          ...         ...        ...         ...          ...         ...
# 694         NaN         NaN        NaN         NaN          NaN         NaN
# 695         NaN         NaN        NaN         NaN          NaN         NaN
# 696         NaN         NaN        NaN         NaN          NaN         NaN
# 698         NaN         NaN        NaN         NaN          NaN         NaN
# 699         NaN         NaN        NaN         NaN          NaN         NaN
#
#      quote_ratio  engagement_ratio  stage_success
# 0            NaN               NaN              0
# 2            NaN               NaN              0
# 3            NaN               NaN              0
# 6            NaN               NaN              0
# 7            NaN               NaN              0
# ..           ...               ...            ...
# 694          NaN               NaN              0
# 695          NaN               NaN              0
# 696          NaN               NaN              0
# 698          NaN               NaN              0
# 699          NaN               NaN              0
#
# [391 rows x 30 columns]

# %%
null_r_count = df[df['reply_count'].isnull()]
null_r_count
# Out:
#      Unnamed: 0                        name      country
# 0           669               N.P.T. S.R.L.        ITALY  \
# 2          1643                GRAPHENEA SA        SPAIN
# 3           331           CROIVALVE LIMITED      IRELAND
# 6           266                 NEOMEDLIGHT       FRANCE
# 7          1704                ROVALMA, S.A        SPAIN
# ..          ...                         ...          ...
# 694         763         CERCARE MEDICAL APS      DENMARK
# 695         835                   SWEGAN AB       SWEDEN
# 696        1216         MILKWAYS HOLDING BV  NETHERLANDS
# 698         559  MILLOR ENERGY SOLUTIONS SL        SPAIN
# 699         684                    IKOI SPA        ITALY
#
#                         city                            web        PIC
# 0             VALSAMOGGIA BO                            NaN  917744355  \
# 2    SAN SEBASTIAN GUIPUZCOA       http://www.graphenea.com  971995582
# 3                     DUBLIN       http://www.croivalve.com  909573463
# 6               VILLEURBANNE     http://www.neomedlight.com  906740675
# 7                   TERRASSA         http://www.rovalma.com  996728545
# ..                       ...                            ...        ...
# 694                 AARHUS C  http://www.cercaremedical.com  920595961
# 695                LINKOPING           http://www.swegan.se  923998527
# 696                   HATTEM        http://www.milkways.com  935402623
# 698                 TERRASSA                            NaN  914997509
# 699                  CASSOLA             http://www.ikoi.it  918087735
#
#      stage_order stage_name  tweet_count  tweet_length  ...  reply_ratio
# 0              1  INCEPTION          NaN           NaN  ...          NaN  \
# 2              1  INCEPTION          NaN           NaN  ...          NaN
# 3              1  INCEPTION          NaN           NaN  ...          NaN
# 6              1  INCEPTION          NaN           NaN  ...          NaN
# 7              1  INCEPTION          NaN           NaN  ...          NaN
# ..           ...        ...          ...           ...  ...          ...
# 694            1  INCEPTION          NaN           NaN  ...          NaN
# 695            1  INCEPTION          NaN           NaN  ...          NaN
# 696            1  INCEPTION          NaN           NaN  ...          NaN
# 698            1  INCEPTION          NaN           NaN  ...          NaN
# 699            1  INCEPTION          NaN           NaN  ...          NaN
#
#      reply_rate  like_count  like_rate  like_ratio  quote_count  quote_rate
# 0           NaN         NaN        NaN         NaN          NaN         NaN  \
# 2           NaN         NaN        NaN         NaN          NaN         NaN
# 3           NaN         NaN        NaN         NaN          NaN         NaN
# 6           NaN         NaN        NaN         NaN          NaN         NaN
# 7           NaN         NaN        NaN         NaN          NaN         NaN
# ..          ...         ...        ...         ...          ...         ...
# 694         NaN         NaN        NaN         NaN          NaN         NaN
# 695         NaN         NaN        NaN         NaN          NaN         NaN
# 696         NaN         NaN        NaN         NaN          NaN         NaN
# 698         NaN         NaN        NaN         NaN          NaN         NaN
# 699         NaN         NaN        NaN         NaN          NaN         NaN
#
#      quote_ratio  engagement_ratio  stage_success
# 0            NaN               NaN              0
# 2            NaN               NaN              0
# 3            NaN               NaN              0
# 6            NaN               NaN              0
# 7            NaN               NaN              0
# ..           ...               ...            ...
# 694          NaN               NaN              0
# 695          NaN               NaN              0
# 696          NaN               NaN              0
# 698          NaN               NaN              0
# 699          NaN               NaN              0
#
# [391 rows x 30 columns]

# %%
null_like_count = df[df['like_count'].isnull()]
null_like_count
# Out:
#      Unnamed: 0                        name      country
# 0           669               N.P.T. S.R.L.        ITALY  \
# 2          1643                GRAPHENEA SA        SPAIN
# 3           331           CROIVALVE LIMITED      IRELAND
# 6           266                 NEOMEDLIGHT       FRANCE
# 7          1704                ROVALMA, S.A        SPAIN
# ..          ...                         ...          ...
# 694         763         CERCARE MEDICAL APS      DENMARK
# 695         835                   SWEGAN AB       SWEDEN
# 696        1216         MILKWAYS HOLDING BV  NETHERLANDS
# 698         559  MILLOR ENERGY SOLUTIONS SL        SPAIN
# 699         684                    IKOI SPA        ITALY
#
#                         city                            web        PIC
# 0             VALSAMOGGIA BO                            NaN  917744355  \
# 2    SAN SEBASTIAN GUIPUZCOA       http://www.graphenea.com  971995582
# 3                     DUBLIN       http://www.croivalve.com  909573463
# 6               VILLEURBANNE     http://www.neomedlight.com  906740675
# 7                   TERRASSA         http://www.rovalma.com  996728545
# ..                       ...                            ...        ...
# 694                 AARHUS C  http://www.cercaremedical.com  920595961
# 695                LINKOPING           http://www.swegan.se  923998527
# 696                   HATTEM        http://www.milkways.com  935402623
# 698                 TERRASSA                            NaN  914997509
# 699                  CASSOLA             http://www.ikoi.it  918087735
#
#      stage_order stage_name  tweet_count  tweet_length  ...  reply_ratio
# 0              1  INCEPTION          NaN           NaN  ...          NaN  \
# 2              1  INCEPTION          NaN           NaN  ...          NaN
# 3              1  INCEPTION          NaN           NaN  ...          NaN
# 6              1  INCEPTION          NaN           NaN  ...          NaN
# 7              1  INCEPTION          NaN           NaN  ...          NaN
# ..           ...        ...          ...           ...  ...          ...
# 694            1  INCEPTION          NaN           NaN  ...          NaN
# 695            1  INCEPTION          NaN           NaN  ...          NaN
# 696            1  INCEPTION          NaN           NaN  ...          NaN
# 698            1  INCEPTION          NaN           NaN  ...          NaN
# 699            1  INCEPTION          NaN           NaN  ...          NaN
#
#      reply_rate  like_count  like_rate  like_ratio  quote_count  quote_rate
# 0           NaN         NaN        NaN         NaN          NaN         NaN  \
# 2           NaN         NaN        NaN         NaN          NaN         NaN
# 3           NaN         NaN        NaN         NaN          NaN         NaN
# 6           NaN         NaN        NaN         NaN          NaN         NaN
# 7           NaN         NaN        NaN         NaN          NaN         NaN
# ..          ...         ...        ...         ...          ...         ...
# 694         NaN         NaN        NaN         NaN          NaN         NaN
# 695         NaN         NaN        NaN         NaN          NaN         NaN
# 696         NaN         NaN        NaN         NaN          NaN         NaN
# 698         NaN         NaN        NaN         NaN          NaN         NaN
# 699         NaN         NaN        NaN         NaN          NaN         NaN
#
#      quote_ratio  engagement_ratio  stage_success
# 0            NaN               NaN              0
# 2            NaN               NaN              0
# 3            NaN               NaN              0
# 6            NaN               NaN              0
# 7            NaN               NaN              0
# ..           ...               ...            ...
# 694          NaN               NaN              0
# 695          NaN               NaN              0
# 696          NaN               NaN              0
# 698          NaN               NaN              0
# 699          NaN               NaN              0
#
# [391 rows x 30 columns]

# %%
null_q_count = df[df['quote_count'].isnull()]
null_q_count
# Out:
#      Unnamed: 0                        name      country
# 0           669               N.P.T. S.R.L.        ITALY  \
# 2          1643                GRAPHENEA SA        SPAIN
# 3           331           CROIVALVE LIMITED      IRELAND
# 6           266                 NEOMEDLIGHT       FRANCE
# 7          1704                ROVALMA, S.A        SPAIN
# ..          ...                         ...          ...
# 694         763         CERCARE MEDICAL APS      DENMARK
# 695         835                   SWEGAN AB       SWEDEN
# 696        1216         MILKWAYS HOLDING BV  NETHERLANDS
# 698         559  MILLOR ENERGY SOLUTIONS SL        SPAIN
# 699         684                    IKOI SPA        ITALY
#
#                         city                            web        PIC
# 0             VALSAMOGGIA BO                            NaN  917744355  \
# 2    SAN SEBASTIAN GUIPUZCOA       http://www.graphenea.com  971995582
# 3                     DUBLIN       http://www.croivalve.com  909573463
# 6               VILLEURBANNE     http://www.neomedlight.com  906740675
# 7                   TERRASSA         http://www.rovalma.com  996728545
# ..                       ...                            ...        ...
# 694                 AARHUS C  http://www.cercaremedical.com  920595961
# 695                LINKOPING           http://www.swegan.se  923998527
# 696                   HATTEM        http://www.milkways.com  935402623
# 698                 TERRASSA                            NaN  914997509
# 699                  CASSOLA             http://www.ikoi.it  918087735
#
#      stage_order stage_name  tweet_count  tweet_length  ...  reply_ratio
# 0              1  INCEPTION          NaN           NaN  ...          NaN  \
# 2              1  INCEPTION          NaN           NaN  ...          NaN
# 3              1  INCEPTION          NaN           NaN  ...          NaN
# 6              1  INCEPTION          NaN           NaN  ...          NaN
# 7              1  INCEPTION          NaN           NaN  ...          NaN
# ..           ...        ...          ...           ...  ...          ...
# 694            1  INCEPTION          NaN           NaN  ...          NaN
# 695            1  INCEPTION          NaN           NaN  ...          NaN
# 696            1  INCEPTION          NaN           NaN  ...          NaN
# 698            1  INCEPTION          NaN           NaN  ...          NaN
# 699            1  INCEPTION          NaN           NaN  ...          NaN
#
#      reply_rate  like_count  like_rate  like_ratio  quote_count  quote_rate
# 0           NaN         NaN        NaN         NaN          NaN         NaN  \
# 2           NaN         NaN        NaN         NaN          NaN         NaN
# 3           NaN         NaN        NaN         NaN          NaN         NaN
# 6           NaN         NaN        NaN         NaN          NaN         NaN
# 7           NaN         NaN        NaN         NaN          NaN         NaN
# ..          ...         ...        ...         ...          ...         ...
# 694         NaN         NaN        NaN         NaN          NaN         NaN
# 695         NaN         NaN        NaN         NaN          NaN         NaN
# 696         NaN         NaN        NaN         NaN          NaN         NaN
# 698         NaN         NaN        NaN         NaN          NaN         NaN
# 699         NaN         NaN        NaN         NaN          NaN         NaN
#
#      quote_ratio  engagement_ratio  stage_success
# 0            NaN               NaN              0
# 2            NaN               NaN              0
# 3            NaN               NaN              0
# 6            NaN               NaN              0
# 7            NaN               NaN              0
# ..           ...               ...            ...
# 694          NaN               NaN              0
# 695          NaN               NaN              0
# 696          NaN               NaN              0
# 698          NaN               NaN              0
# 699          NaN               NaN              0
#
# [391 rows x 30 columns]

# %%
df1=df
df1['web'] = df1['web'].notna().astype(int)

# %% [markdown]
# Now we have droped the NaN from the column 'web' and now we will start for replacing those variables that we can't calculate for 0. Those variables are: 'tweet_count', 'tweet_length', 'retweet_count', 'reply_count', 'like_count' and 'quote_rate'.

# %%
df1 = df1.fillna({'tweet_count': 0, 'tweet_length': 0, 'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'replied_to_ratio': 0, 'quoted_ratio':0})

# %% [markdown]
# Now we replace the NaN from 'tweet_rate' with the formula.

# %%
def replace_nan_tweet(row):
    if pd.isna(row['tweet_rate']): 
        return row['tweet_count'] / 365
    else:
        return row['tweet_rate']

df1['tweet_rate'] = df1.apply(replace_nan_tweet, axis=1)


df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               700 non-null    int64
#  1   name                     700 non-null    object
#  2   country                  700 non-null    object
#  3   city                     700 non-null    object
#  4   web                      700 non-null    int32
#  5   PIC                      700 non-null    int64
#  6   stage_order              700 non-null    int64
#  7   stage_name               700 non-null    object
#  8   tweet_count              700 non-null    float64
#  9   tweet_length             700 non-null    float64
#  10  tweet_rate               700 non-null    float64
#  11  original_ratio           307 non-null    float64
#  12  retweeted_ratio          289 non-null    float64
#  13  replied_to_ratio         700 non-null    float64
#  14  quoted_ratio             700 non-null    float64
#  15  quoted_replied_to_ratio  18 non-null     float64
#  16  retweet_count            700 non-null    float64
#  17  retweet_ratio            309 non-null    float64
#  18  retweet_rate             309 non-null    float64
#  19  reply_count              700 non-null    float64
#  20  reply_ratio              309 non-null    float64
#  21  reply_rate               309 non-null    float64
#  22  like_count               700 non-null    float64
#  23  like_rate                309 non-null    float64
#  24  like_ratio               309 non-null    float64
#  25  quote_count              700 non-null    float64
#  26  quote_rate               309 non-null    float64
#  27  quote_ratio              309 non-null    float64
#  28  engagement_ratio         309 non-null    float64
#  29  stage_success            700 non-null    int64
# dtypes: float64(21), int32(1), int64(4), object(4)
# memory usage: 161.5+ KB

# %% [markdown]
# The next ratio that we need to fix is the 'original_ratio', since we don't have the variable 'original_count' we are going to replace NaN with 0.

# %%
df1 = df1.fillna({'original_ratio': 0})

# %% [markdown]
# Now we will replace the NaN of the colum 'retweeted_ratio' with 0 because we don't have the count of the retweets done not received.

# %%
df1 = df1.fillna({'retweeted_ratio': 0})

# %%
df1 = df1.drop('Unnamed: 0', axis=1)

# %%
unique_counts = df1['stage_success'].value_counts()
unique_counts
# Out:
# stage_success
# 0    589
# 1    111
# Name: count, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     700 non-null    object
#  1   country                  700 non-null    object
#  2   city                     700 non-null    object
#  3   web                      700 non-null    int32
#  4   PIC                      700 non-null    int64
#  5   stage_order              700 non-null    int64
#  6   stage_name               700 non-null    object
#  7   tweet_count              700 non-null    float64
#  8   tweet_length             700 non-null    float64
#  9   tweet_rate               700 non-null    float64
#  10  original_ratio           700 non-null    float64
#  11  retweeted_ratio          700 non-null    float64
#  12  replied_to_ratio         700 non-null    float64
#  13  quoted_ratio             700 non-null    float64
#  14  quoted_replied_to_ratio  18 non-null     float64
#  15  retweet_count            700 non-null    float64
#  16  retweet_ratio            309 non-null    float64
#  17  retweet_rate             309 non-null    float64
#  18  reply_count              700 non-null    float64
#  19  reply_ratio              309 non-null    float64
#  20  reply_rate               309 non-null    float64
#  21  like_count               700 non-null    float64
#  22  like_rate                309 non-null    float64
#  23  like_ratio               309 non-null    float64
#  24  quote_count              700 non-null    float64
#  25  quote_rate               309 non-null    float64
#  26  quote_ratio              309 non-null    float64
#  27  engagement_ratio         309 non-null    float64
#  28  stage_success            700 non-null    int64
# dtypes: float64(21), int32(1), int64(3), object(4)
# memory usage: 156.0+ KB

# %%
df1 = df1.drop('quoted_replied_to_ratio', axis=1)
df1 = df1.drop('PIC', axis=1)

# %%
df1.describe()
# Out:
#               web  stage_order   tweet_count  tweet_length  tweet_rate
# count  700.000000        700.0    700.000000    700.000000  700.000000  \
# mean     0.927143          1.0    365.161429     72.783180    0.285777
# std      0.260088          0.0   1705.114111     86.418634    1.192321
# min      0.000000          1.0      0.000000      0.000000    0.000000
# 25%      1.000000          1.0      0.000000      0.000000    0.000000
# 50%      1.000000          1.0      0.000000      0.000000    0.000000
# 75%      1.000000          1.0    162.250000    153.129324    0.186677
# max      1.000000          1.0  32317.000000    290.000000   24.631860
#
#        original_ratio  retweeted_ratio  replied_to_ratio  quoted_ratio
# count      700.000000       700.000000        700.000000    700.000000  \
# mean         0.275466         0.113375          0.028091      0.024444
# std          0.344637         0.184808          0.071819      0.051702
# min          0.000000         0.000000          0.000000      0.000000
# 25%          0.000000         0.000000          0.000000      0.000000
# 50%          0.000000         0.000000          0.000000      0.000000
# 75%          0.600000         0.181856          0.023222      0.032258
# max          1.000000         1.000000          0.716749      0.666667
#
#        retweet_count  ...  reply_ratio  reply_rate    like_count   like_rate
# count   7.000000e+02  ...   309.000000  309.000000    700.000000  309.000000  \
# mean    1.010491e+04  ...     0.080327    0.057807    691.714286    1.463221
# std     1.568470e+05  ...     0.108577    0.176579   4325.509346    6.883328
# min     0.000000e+00  ...     0.000000    0.000000      0.000000    0.000000
# 25%     0.000000e+00  ...     0.021622    0.002806      0.000000    0.094563
# 50%     0.000000e+00  ...     0.048193    0.012644      0.000000    0.286169
# 75%     4.187500e+02  ...     0.101974    0.033551    206.500000    0.925382
# max     4.116868e+06  ...     1.044490    2.000000  84947.000000   97.000000
#
#        like_ratio   quote_count  quote_rate  quote_ratio  engagement_ratio
# count  309.000000    700.000000  309.000000   309.000000        309.000000  \
# mean     2.041657    691.714286    1.463221     2.041657         28.363142
# std      2.929950   4325.509346    6.883328     2.929950        146.586992
# min      0.000000      0.000000    0.000000     0.000000          0.191364
# 25%      0.710247      0.000000    0.094563     0.710247          2.666667
# 50%      1.492063      0.000000    0.286169     1.492063          4.738125
# 75%      2.480000    206.500000    0.925382     2.480000         10.792899
# max     39.148528  84947.000000   97.000000    39.148528       2300.744681
#
#        stage_success
# count     700.000000
# mean        0.158571
# std         0.365537
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 23 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              700 non-null    object
#  1   country           700 non-null    object
#  2   city              700 non-null    object
#  3   web               700 non-null    int32
#  4   stage_order       700 non-null    int64
#  5   stage_name        700 non-null    object
#  6   tweet_count       700 non-null    float64
#  7   tweet_length      700 non-null    float64
#  8   tweet_rate        700 non-null    float64
#  9   original_ratio    700 non-null    float64
#  10  retweeted_ratio   700 non-null    float64
#  11  replied_to_ratio  700 non-null    float64
#  12  quoted_ratio      700 non-null    float64
#  13  retweet_count     700 non-null    float64
#  14  retweet_ratio     309 non-null    float64
#  15  retweet_rate      309 non-null    float64
#  16  reply_count       700 non-null    float64
#  17  reply_ratio       309 non-null    float64
#  18  reply_rate        309 non-null    float64
#  19  like_count        700 non-null    float64
#  20  like_rate         309 non-null    float64
#  21  like_ratio        309 non-null    float64
#  22  quote_count       700 non-null    float64
#  23  quote_rate        309 non-null    float64
#  24  quote_ratio       309 non-null    float64
#  25  engagement_ratio  309 non-null    float64
#  26  stage_success     700 non-null    int64
# dtypes: float64(20), int32(1), int64(2), object(4)
# memory usage: 145.1+ KB

# %%
from sklearn.preprocessing import LabelEncoder

df1['country_enc'] = LabelEncoder().fit_transform(df1['country'])
df1['city_enc'] = LabelEncoder().fit_transform(df1['city'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              700 non-null    object
#  1   country           700 non-null    object
#  2   city              700 non-null    object
#  3   web               700 non-null    int32
#  4   stage_order       700 non-null    int64
#  5   stage_name        700 non-null    object
#  6   tweet_count       700 non-null    float64
#  7   tweet_length      700 non-null    float64
#  8   tweet_rate        700 non-null    float64
#  9   original_ratio    700 non-null    float64
#  10  retweeted_ratio   700 non-null    float64
#  11  replied_to_ratio  700 non-null    float64
#  12  quoted_ratio      700 non-null    float64
#  13  retweet_count     700 non-null    float64
#  14  retweet_ratio     309 non-null    float64
#  15  retweet_rate      309 non-null    float64
#  16  reply_count       700 non-null    float64
#  17  reply_ratio       309 non-null    float64
#  18  reply_rate        309 non-null    float64
#  19  like_count        700 non-null    float64
#  20  like_rate         309 non-null    float64
#  21  like_ratio        309 non-null    float64
#  22  quote_count       700 non-null    float64
#  23  quote_rate        309 non-null    float64
#  24  quote_ratio       309 non-null    float64
#  25  engagement_ratio  309 non-null    float64
#  26  stage_success     700 non-null    int64
#  27  country_enc       700 non-null    int32
#  28  city_enc          700 non-null    int32
# dtypes: float64(20), int32(3), int64(2), object(4)
# memory usage: 150.5+ KB

# %%
df1.groupby('stage_name')['stage_order'].nunique()
# Out:
# stage_name
# INCEPTION    1
# Name: stage_order, dtype: int64

# %%
df1['stage_name'].value_counts()
# Out:
# stage_name
# INCEPTION    700
# Name: count, dtype: int64

# %%
df1 = df1.drop('stage_name', axis=1)
df1 = df1.drop('stage_order', axis=1)

# %% [markdown]
# ### Data Analysis

# %%
numeric_df = df1.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                   tweet_count  tweet_length  tweet_rate  original_ratio
# tweet_count          1.000000      0.210491    0.931892        0.236748  \
# tweet_length         0.210491      1.000000    0.238044        0.895242
# tweet_rate           0.931892      0.238044    1.000000        0.264859
# original_ratio       0.236748      0.895242    0.264859        1.000000
# retweeted_ratio      0.140220      0.576217    0.152164        0.351261
# replied_to_ratio     0.150650      0.385079    0.173079        0.248997
# quoted_ratio         0.028264      0.548826    0.043189        0.379681
# retweet_count        0.201761      0.058095    0.178034        0.036025
# retweet_ratio        0.003458     -0.050490    0.001669       -0.133049
# retweet_rate         0.182001     -0.036969    0.167575       -0.085697
# reply_count          0.743261      0.200973    0.672708        0.171075
# reply_ratio          0.003878      0.039734    0.031006       -0.180355
# reply_rate           0.529064     -0.075642    0.658410       -0.091614
# like_count           0.793557      0.174440    0.770472        0.158858
# like_rate            0.480947      0.002217    0.637473        0.007293
# like_ratio          -0.016746      0.184405    0.028007       -0.005523
# quote_count          0.793557      0.174440    0.770472        0.158858
# quote_rate           0.480947      0.002217    0.637473        0.007293
# quote_ratio         -0.016746      0.184405    0.028007       -0.005523
# engagement_ratio     0.003106     -0.046608    0.002312       -0.133226
# stage_success        0.036605      0.196940    0.123814        0.245613
#
#                   retweeted_ratio  replied_to_ratio  quoted_ratio
# tweet_count              0.140220          0.150650      0.028264  \
# tweet_length             0.576217          0.385079      0.548826
# tweet_rate               0.152164          0.173079      0.043189
# original_ratio           0.351261          0.248997      0.379681
# retweeted_ratio          1.000000          0.264999      0.352121
# replied_to_ratio         0.264999          1.000000      0.234017
# quoted_ratio             0.352121          0.234017      1.000000
# retweet_count            0.117913          0.024150      0.001752
# retweet_ratio            0.125019          0.054819     -0.005534
# retweet_rate             0.114635         -0.007376     -0.044736
# reply_count              0.159278          0.353854      0.042140
# reply_ratio              0.004915          0.386522      0.033621
# reply_rate              -0.006810          0.304089     -0.112357
# like_count               0.134024          0.098543      0.055022
# like_rate                0.014391         -0.002022     -0.065941
# like_ratio              -0.031347          0.002852      0.109459
# quote_count              0.134024          0.098543      0.055022
# quote_rate               0.014391         -0.002022     -0.065941
# quote_ratio             -0.031347          0.002852      0.109459
# engagement_ratio         0.124296          0.055079     -0.003124
# stage_success            0.247027          0.165686      0.050439
#
#                   retweet_count  retweet_ratio  retweet_rate  ...
# tweet_count            0.201761       0.003458      0.182001  ...  \
# tweet_length           0.058095      -0.050490     -0.036969  ...
# tweet_rate             0.178034       0.001669      0.167575  ...
# original_ratio         0.036025      -0.133049     -0.085697  ...
# retweeted_ratio        0.117913       0.125019      0.114635  ...
# replied_to_ratio       0.024150       0.054819     -0.007376  ...
# quoted_ratio           0.001752      -0.005534     -0.044736  ...
# retweet_count          1.000000       0.272430      0.988327  ...
# retweet_ratio          0.272430       1.000000      0.371677  ...
# retweet_rate           0.988327       0.371677      1.000000  ...
# reply_count            0.240934       0.019907      0.220177  ...
# reply_ratio            0.021089       0.105421      0.027525  ...
# reply_rate             0.162538       0.012675      0.171510  ...
# like_count             0.127772      -0.000786      0.110850  ...
# like_rate              0.061480      -0.004155      0.076268  ...
# like_ratio            -0.009434       0.026474     -0.003064  ...
# quote_count            0.127772      -0.000786      0.110850  ...
# quote_rate             0.061480      -0.004155      0.076268  ...
# quote_ratio           -0.009434       0.026474     -0.003064  ...
# engagement_ratio       0.272005       0.999775      0.371311  ...
# stage_success         -0.008591       0.083810     -0.011614  ...
#
#                   reply_ratio  reply_rate  like_count  like_rate  like_ratio
# tweet_count          0.003878    0.529064    0.793557   0.480947   -0.016746  \
# tweet_length         0.039734   -0.075642    0.174440   0.002217    0.184405
# tweet_rate           0.031006    0.658410    0.770472   0.637473    0.028007
# original_ratio      -0.180355   -0.091614    0.158858   0.007293   -0.005523
# retweeted_ratio      0.004915   -0.006810    0.134024   0.014391   -0.031347
# replied_to_ratio     0.386522    0.304089    0.098543  -0.002022    0.002852
# quoted_ratio         0.033621   -0.112357    0.055022  -0.065941    0.109459
# retweet_count        0.021089    0.162538    0.127772   0.061480   -0.009434
# retweet_ratio        0.105421    0.012675   -0.000786  -0.004155    0.026474
# retweet_rate         0.027525    0.171510    0.110850   0.076268   -0.003064
# reply_count          0.384005    0.687589    0.818138   0.431054    0.297332
# reply_ratio          1.000000    0.415054    0.280630   0.257831    0.703418
# reply_rate           0.415054    1.000000    0.558941   0.857536    0.371511
# like_count           0.280630    0.558941    1.000000   0.569640    0.416232
# like_rate            0.257831    0.857536    0.569640   1.000000    0.451180
# like_ratio           0.703418    0.371511    0.416232   0.451180    1.000000
# quote_count          0.280630    0.558941    1.000000   0.569640    0.416232
# quote_rate           0.257831    0.857536    0.569640   1.000000    0.451180
# quote_ratio          0.703418    0.371511    0.416232   0.451180    1.000000
# engagement_ratio     0.120639    0.020810    0.007940   0.005588    0.047643
# stage_success        0.011633    0.098136   -0.010109   0.050159   -0.055556
#
#                   quote_count  quote_rate  quote_ratio  engagement_ratio
# tweet_count          0.793557    0.480947    -0.016746          0.003106  \
# tweet_length         0.174440    0.002217     0.184405         -0.046608
# tweet_rate           0.770472    0.637473     0.028007          0.002312
# original_ratio       0.158858    0.007293    -0.005523         -0.133226
# retweeted_ratio      0.134024    0.014391    -0.031347          0.124296
# replied_to_ratio     0.098543   -0.002022     0.002852          0.055079
# quoted_ratio         0.055022   -0.065941     0.109459         -0.003124
# retweet_count        0.127772    0.061480    -0.009434          0.272005
# retweet_ratio       -0.000786   -0.004155     0.026474          0.999775
# retweet_rate         0.110850    0.076268    -0.003064          0.371311
# reply_count          0.818138    0.431054     0.297332          0.026242
# reply_ratio          0.280630    0.257831     0.703418          0.120639
# reply_rate           0.558941    0.857536     0.371511          0.020810
# like_count           1.000000    0.569640     0.416232          0.007940
# like_rate            0.569640    1.000000     0.451180          0.005588
# like_ratio           0.416232    0.451180     1.000000          0.047643
# quote_count          1.000000    0.569640     0.416232          0.007940
# quote_rate           0.569640    1.000000     0.451180          0.005588
# quote_ratio          0.416232    0.451180     1.000000          0.047643
# engagement_ratio     0.007940    0.005588     0.047643          1.000000
# stage_success       -0.010109    0.050159    -0.055556          0.082612
#
#                   stage_success
# tweet_count            0.036605
# tweet_length           0.196940
# tweet_rate             0.123814
# original_ratio         0.245613
# retweeted_ratio        0.247027
# replied_to_ratio       0.165686
# quoted_ratio           0.050439
# retweet_count         -0.008591
# retweet_ratio          0.083810
# retweet_rate          -0.011614
# reply_count            0.044808
# reply_ratio            0.011633
# reply_rate             0.098136
# like_count            -0.010109
# like_rate              0.050159
# like_ratio            -0.055556
# quote_count           -0.010109
# quote_rate             0.050159
# quote_ratio           -0.055556
# engagement_ratio       0.082612
# stage_success          1.000000
#
# [21 rows x 21 columns]

# %%
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

plt.show()

# %% [markdown]
# By looking at the correlation matrix, we can take out some of the variables as we can clearly see that there is multicollinearity between some of our variables, meaning that they are providing exactly the same information into our model and we should therefore take them out to make sure that or model performs well.

# %%
df1 = df1.drop('engagement_ratio', axis=1)
df1 = df1.drop(columns=['quote_rate', 'quote_ratio', 'quote_count', 'retweet_rate'], axis=1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              700 non-null    object
#  1   country           700 non-null    object
#  2   city              700 non-null    object
#  3   web               700 non-null    int32
#  4   tweet_count       700 non-null    float64
#  5   tweet_length      700 non-null    float64
#  6   tweet_rate        700 non-null    float64
#  7   original_ratio    700 non-null    float64
#  8   retweeted_ratio   700 non-null    float64
#  9   replied_to_ratio  700 non-null    float64
#  10  quoted_ratio      700 non-null    float64
#  11  retweet_count     700 non-null    float64
#  12  retweet_ratio     309 non-null    float64
#  13  reply_count       700 non-null    float64
#  14  reply_ratio       309 non-null    float64
#  15  reply_rate        309 non-null    float64
#  16  like_count        700 non-null    float64
#  17  like_rate         309 non-null    float64
#  18  like_ratio        309 non-null    float64
#  19  stage_success     700 non-null    int64
#  20  country_enc       700 non-null    int32
#  21  city_enc          700 non-null    int32
# dtypes: float64(15), int32(3), int64(1), object(3)
# memory usage: 112.2+ KB

# %%
numeric_df = df1.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()

correlation_matrix = numeric_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

plt.show()

# %% [markdown]
# After analysing the heatmap we can conclude that the variables with the higher correlation are the following:
# engagement_ratio,
# reply_rate,
# retweet_ratio,
# retweeted_ratio,
# quoted_ratio,
# original_ratio,
# tweet_rate,
# tweet_length,
# PIC

# %%
high_corr_vars = ['tweet_length', 'tweet_rate','original_ratio','retweeted_ratio','replied_to_ratio','reply_rate']
sns.pairplot(df1[high_corr_vars], diag_kind='kde')
plt.suptitle('Pairplot of High Correlation Variables', y=1.02)
plt.show()

# %%
plt.figure(figsize=(15, 10))
for i, var in enumerate(high_corr_vars, start=1):
    plt.subplot(3, 3, i)
    sns.boxplot(x='stage_success', y=var, data=df1, hue='stage_success')
  
    plt.xlabel('Stage Success')
    plt.ylabel(var)
    plt.legend(title='Stage Success', loc='best')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 10))
for i, var in enumerate(high_corr_vars, start=1):
    plt.subplot(3, 3, i)
    sns.histplot(data=df1, x=var, hue='stage_success', multiple='stack', kde=True, bins=20)

    plt.xlabel(var)
    plt.ylabel('Count')
    plt.legend(title='Stage Success', loc='best')

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(15, 10))
for i, var in enumerate(high_corr_vars, start=1):
    plt.subplot(3, 3, i)
    sns.histplot(data=df1, x=var, hue='stage_success', multiple='dodge', kde=True, bins=20)

    plt.xlabel(var)
    plt.ylabel('Count')
    plt.legend(title='Stage Success', loc='best')

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Train/Test split

# %% [markdown]
# ## THE ACTUAL MODEL

# %%
#Dataset with 309 observations, filled NAs with 0s
df_filled = df1.fillna(0)
#df_filled = df1.dropna()

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the 'name' column
df_filled['name_enc'] = label_encoder.fit_transform(df_filled['name'])

# Display the DataFrame with the new 'name_enc' column
print(df_filled.head())
# Out:
#                      name  country                     city  web  tweet_count
# 0           N.P.T. S.R.L.    ITALY           VALSAMOGGIA BO    0          0.0  \
# 1  ADVANCED MATERIALS SRL    ITALY                   LAIVES    1        636.0
# 2            GRAPHENEA SA    SPAIN  SAN SEBASTIAN GUIPUZCOA    1          0.0
# 3       CROIVALVE LIMITED  IRELAND                   DUBLIN    1          0.0
# 4              OU COGNUSE  ESTONIA                  TALLINN    1        126.0
#
#    tweet_length  tweet_rate  original_ratio  retweeted_ratio
# 0      0.000000    0.000000        0.000000         0.000000  \
# 1    170.550314    1.121693        0.630503         0.245283
# 2      0.000000    0.000000        0.000000         0.000000
# 3      0.000000    0.000000        0.000000         0.000000
# 4    137.015873    0.049901        0.428571         0.444444
#
#    replied_to_ratio  ...  reply_count  reply_ratio  reply_rate  like_count
# 0          0.000000  ...          0.0     0.000000    0.000000         0.0  \
# 1          0.050314  ...         20.0     0.031447    0.035273       547.0
# 2          0.000000  ...          0.0     0.000000    0.000000         0.0
# 3          0.000000  ...          0.0     0.000000    0.000000         0.0
# 4          0.015873  ...          4.0     0.031746    0.001584        96.0
#
#    like_rate  like_ratio  stage_success  country_enc  city_enc  name_enc
# 0   0.000000    0.000000              0           14       401       409
# 1   0.964727    0.860063              0           14       211        19
# 2   0.000000    0.000000              0           25       342       274
# 3   0.000000    0.000000              0           12        93       147
# 4   0.038020    0.761905              0            5       369       463
#
# [5 rows x 23 columns]

# %%
df_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              700 non-null    object
#  1   country           700 non-null    object
#  2   city              700 non-null    object
#  3   web               700 non-null    int32
#  4   tweet_count       700 non-null    float64
#  5   tweet_length      700 non-null    float64
#  6   tweet_rate        700 non-null    float64
#  7   original_ratio    700 non-null    float64
#  8   retweeted_ratio   700 non-null    float64
#  9   replied_to_ratio  700 non-null    float64
#  10  quoted_ratio      700 non-null    float64
#  11  retweet_count     700 non-null    float64
#  12  retweet_ratio     700 non-null    float64
#  13  reply_count       700 non-null    float64
#  14  reply_ratio       700 non-null    float64
#  15  reply_rate        700 non-null    float64
#  16  like_count        700 non-null    float64
#  17  like_rate         700 non-null    float64
#  18  like_ratio        700 non-null    float64
#  19  stage_success     700 non-null    int64
#  20  country_enc       700 non-null    int32
#  21  city_enc          700 non-null    int32
#  22  name_enc          700 non-null    int32
# dtypes: float64(15), int32(4), int64(1), object(3)
# memory usage: 115.0+ KB

# %%
df_filled['name']
# Out:
# 0                   N.P.T. S.R.L.
# 1          ADVANCED MATERIALS SRL
# 2                    GRAPHENEA SA
# 3               CROIVALVE LIMITED
# 4                      OU COGNUSE
#                   ...
# 695                     SWEGAN AB
# 696           MILKWAYS HOLDING BV
# 697          Z.E.U. -INMUNOTEC SL
# 698    MILLOR ENERGY SOLUTIONS SL
# 699                      IKOI SPA
# Name: name, Length: 700, dtype: object

# %%
target = df_filled['stage_success']
features = df_filled.select_dtypes(include='number').drop('stage_success', axis=1)

# %%
features.shape
# Out:
# (700, 19)

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(features, target , test_size = 0.2 , random_state = 100)
X_train
# Out:
#      web  tweet_count  tweet_length  tweet_rate  original_ratio
# 491    1        228.0    200.828947    0.097228        0.859649  \
# 615    1          0.0      0.000000    0.000000        0.000000
# 277    1          0.0      0.000000    0.000000        0.000000
# 404    1          0.0      0.000000    0.000000        0.000000
# 529    1         38.0    112.526316    0.043231        0.447368
# ..   ...          ...           ...         ...             ...
# 578    1          0.0      0.000000    0.000000        0.000000
# 53     1          0.0      0.000000    0.000000        0.000000
# 350    1          0.0      0.000000    0.000000        0.000000
# 79     1          1.0    135.000000    0.000000        1.000000
# 520    1        113.0    222.256637    0.135167        0.849558
#
#      retweeted_ratio  replied_to_ratio  quoted_ratio  retweet_count
# 491         0.065789          0.039474      0.035088          194.0  \
# 615         0.000000          0.000000      0.000000            0.0
# 277         0.000000          0.000000      0.000000            0.0
# 404         0.000000          0.000000      0.000000            0.0
# 529         0.315789          0.184211      0.052632          103.0
# ..               ...               ...           ...            ...
# 578         0.000000          0.000000      0.000000            0.0
# 53          0.000000          0.000000      0.000000            0.0
# 350         0.000000          0.000000      0.000000            0.0
# 79          0.000000          0.000000      0.000000            1.0
# 520         0.123894          0.000000      0.026549           62.0
#
#      retweet_ratio  reply_count  reply_ratio  reply_rate  like_count
# 491       0.850877          7.0     0.030702    0.002985       231.0  \
# 615       0.000000          0.0     0.000000    0.000000         0.0
# 277       0.000000          0.0     0.000000    0.000000         0.0
# 404       0.000000          0.0     0.000000    0.000000         0.0
# 529       2.710526          6.0     0.157895    0.006826        45.0
# ..             ...          ...          ...         ...         ...
# 578       0.000000          0.0     0.000000    0.000000         0.0
# 53        0.000000          0.0     0.000000    0.000000         0.0
# 350       0.000000          0.0     0.000000    0.000000         0.0
# 79        1.000000          0.0     0.000000    0.000000         5.0
# 520       0.548673          1.0     0.008850    0.001196        50.0
#
#      like_rate  like_ratio  country_enc  city_enc  name_enc
# 491   0.098507    1.013158           31       354       233
# 615   0.000000    0.000000            4       166       115
# 277   0.000000    0.000000           26       394       476
# 404   0.000000    0.000000            4       329       424
# 529   0.051195    1.184211           14        50       696
# ..         ...         ...          ...       ...       ...
# 578   0.000000    0.000000           31        51       305
# 53    0.000000    0.000000            7       291       181
# 350   0.000000    0.000000            6       106       124
# 79    0.000000    5.000000            7       180       612
# 520   0.059809    0.442478           27       413       154
#
# [560 rows x 19 columns]

# %% [markdown]
# Min Max - When the data has a small standard deviation and is uniformly distributed.
# When you need to preserve the shape of the data distribution and bring all feature values into the same range.
# Standard Scaler - When the data follows a Gaussian (normal) distribution.
# When algorithms assume that the data is centered around zero and have unit variance, such as linear regression, logistic regression, and K-means clustering.
# Robust - When the data contains outliers and you want to minimize their influence. Anything but decision tree and random forest
# Useful for algorithms that are sensitive to outliers.

# %%
standard_scaler = StandardScaler()
X_train = standard_scaler.fit_transform(X_train)

# %%
standard_scaler = StandardScaler()
X_test = standard_scaler.fit_transform(X_test)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (560, 19)
# (140, 19)

# %% [markdown]
# ## Dummy classifier

# %%
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import GridSearchCV

dummy_model = DummyClassifier()

# Define hyperparameters to search for our DummyClassifier
param_grid = {'strategy': ['most_frequent', 'stratified', 'uniform', 'constant'], 'constant': [0, 1, 2]}  # Include all strategies and possible constant values

# Create GridSearchCV object
grid_search_dummy = GridSearchCV(estimator=dummy_model, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit the grid search to the data
grid_search_dummy.fit(X_train, y_train)

print("Best Parameters:", grid_search_dummy.best_params_)
print("Best Score:", grid_search_dummy.best_score_)
# Out:
# Best Parameters: {'constant': 0, 'strategy': 'most_frequent'}
# Best Score: 0.8446428571428571

# %%
dummy_clf = DummyClassifier(strategy='most_frequent', constant=0)
dummy_clf.fit(X_train, y_train)
print("Accuracy of the dummy classifier:", dummy_clf.score(X_test, y_test))
# Out:
# Accuracy of the dummy classifier: 0.8285714285714286

# %%
y_pred = dummy_clf.predict(X_test)

# %%
y_pred_prob = dummy_clf.predict_proba(X_test)

# %%
cm_dummyclf = metrics.confusion_matrix(y_test, y_pred, labels=dummy_clf.classes_)
display(cm_dummyclf)
# Out:
# array([[116,   0],
#        [ 24,   0]], dtype=int64)

# %%
labels = ['Negative', 'Positive']
sns.heatmap(cm_dummyclf, annot=True, fmt='g', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.show()

# %% [markdown]
# This is really bad so we wont be using this model in our evaulation at all. Our dummy classifier model is performing really bad, as it is predicting that all of the companies will NOT succeed. Therefore, we will try some other models to see if we can improve our predictions.

# %% [markdown]
# ## LOGISTIC Regression

# %%
Y = df_filled['stage_success']
X = df_filled.select_dtypes(include='number').drop('stage_success', axis=1)

Train_X, Test_X, Train_Y, Test_Y = train_test_split(X, Y, train_size=0.8, test_size=0.2, random_state=100)

std = StandardScaler()
Train_X_std = std.fit_transform(Train_X)
Train_X_std = pd.DataFrame(Train_X_std, columns=X.columns)

Test_X_std = std.transform(Test_X)
Test_X_std = pd.DataFrame(Test_X_std, columns=X.columns)
Test_X_std
# Out:
#           web  tweet_count  tweet_length  tweet_rate  original_ratio
# 0   -3.872983    -0.274100     -0.825632   -0.331549       -0.785200  \
# 1    0.258199     0.087228      0.265827    1.404766       -0.251743
# 2    0.258199    -0.254521      0.806038   -0.267491        1.840055
# 3    0.258199    -0.251851      1.021612   -0.278091        0.485423
# 4    0.258199    -0.274100     -0.825632   -0.331549       -0.785200
# ..        ...          ...           ...         ...             ...
# 135  0.258199    -0.274100     -0.825632   -0.331549       -0.785200
# 136  0.258199    -0.206462      1.389843   -0.056396        0.924670
# 137  0.258199    -0.274100     -0.825632   -0.331549       -0.785200
# 138  0.258199    -0.274100     -0.825632   -0.331549       -0.785200
# 139  0.258199     0.113038      1.403640    0.121157        1.173180
#
#      retweeted_ratio  replied_to_ratio  quoted_ratio  retweet_count
# 0          -0.600159         -0.402905     -0.528628      -0.204018  \
# 1          -0.055736         10.418537     -0.528628      -0.189193
# 2          -0.600159         -0.402905      1.552097      -0.201973
# 3          -0.379123          3.824523      4.964486      -0.202902
# 4          -0.600159         -0.402905     -0.528628      -0.204018
# ..               ...               ...           ...            ...
# 135        -0.600159         -0.402905     -0.528628      -0.204018
# 136         0.635896         -0.005590      3.085263      -0.196071
# 137        -0.600159         -0.402905     -0.528628      -0.204018
# 138        -0.600159         -0.402905     -0.528628      -0.204018
# 139         0.428800          0.048299      1.891710      -0.145091
#
#      retweet_ratio  reply_count  reply_ratio  reply_rate  like_count
# 0        -0.116498    -0.210233    -0.407163   -0.255192   -0.193200  \
# 1        -0.109166     0.961810     3.995439    5.586315   -0.172029
# 2        -0.097835    -0.154422     3.461791   -0.065802   -0.126272
# 3        -0.107540    -0.178341     1.538368   -0.175716   -0.172029
# 4        -0.116498    -0.210233    -0.407163   -0.255192   -0.193200
# ..             ...          ...          ...         ...         ...
# 135      -0.116498    -0.210233    -0.407163   -0.255192   -0.193200
# 136      -0.095502    -0.170368     0.392808   -0.086989   -0.138223
# 137      -0.116498    -0.210233    -0.407163   -0.255192   -0.193200
# 138      -0.116498    -0.210233    -0.407163   -0.255192   -0.193200
# 139      -0.089297     0.363829     1.605455    0.441056    1.182235
#
#      like_rate  like_ratio  country_enc  city_enc  name_enc
# 0    -0.283882   -0.399277    -0.985920  0.012924  0.983034
# 1    -0.154363   -0.329616     1.631773  0.109965 -0.827818
# 2    -0.005108    3.664788     1.195491  1.104632 -1.027912
# 3    -0.219123    0.732026    -1.313131 -0.084116 -1.483126
# 4    -0.283882   -0.399277     0.213856  1.428101  0.087613
# ..         ...         ...          ...       ...       ...
# 135  -0.283882   -0.399277     0.541068 -0.731054  0.722911
# 136   0.000844    0.567084    -1.094990 -0.051769 -1.438105
# 137  -0.283882   -0.399277    -1.313131 -0.334805  0.923005
# 138  -0.283882   -0.399277    -0.222426 -1.119217  0.752925
# 139   1.763778    3.824757    -1.313131 -1.442686 -1.743248
#
# [140 rows x 19 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from IPython.display import display

# Train the logistic regression model
logreg = LogisticRegression()
logreg.fit(Train_X_std, Train_Y)

# Print the model coefficients (slope) and intercept
print("Model slope:", logreg.coef_[0])
print("Model intercept:", logreg.intercept_)

# Predict the values for the test dataset
y_pred = logreg.predict(Test_X_std)
y_pred_prob = logreg.predict_proba(Test_X_std)

# Calculate accuracy
accuracy = logreg.score(Test_X_std, Test_Y)

# Calculate confusion matrix
confusion_matrixlog = metrics.confusion_matrix(Test_Y, y_pred)

# Convert predictions and probabilities to DataFrame
predictions_df = pd.DataFrame({
    'Predicted': y_pred,
    'Probability_0': y_pred_prob[:, 0],
    'Probability_1': y_pred_prob[:, 1]
}, index=Test_X.index)

# Convert Test_Y to a DataFrame
Test_Y_df = pd.DataFrame(Test_Y, index=Test_X.index, columns=['stage_success'])

# Convert Test_X_std to a DataFrame with original column names
Test_X_std_df = pd.DataFrame(Test_X, columns=Train_X.columns, index=Test_X.index)

# Merge predictions and actual values with the original test dataset
merged_test_data = pd.concat([Test_X_std_df, Test_Y_df, predictions_df], axis=1)

# Optionally, you can add accuracy and confusion matrix to the merged DataFrame
merged_test_data['Accuracy'] = accuracy
merged_test_data['Confusion_Matrix'] = str(confusion_matrix)

# Merge the 'name' column from df_filled into merged_test_data based on 'name_enc'
merged_test_data = merged_test_data.merge(df_filled[['name_enc', 'name']], on='name_enc', how='left')

# Display the ones we want
successes = merged_test_data[(merged_test_data['Predicted'] == 1) & (merged_test_data['stage_success'] == 1)]

display(successes)
# Out:
# Model slope: [ 0.25182198 -1.59354331 -1.31404806  1.59985668  1.30466935  0.80521352
#   0.06005202 -0.08735658 -0.35694946  0.59803269  0.52689401  0.06364628
#  -0.21399699 -0.47406036  0.23280646 -0.0839753   0.04254858  0.00955289
#   0.06413895]
# Model intercept: [-2.00276583]
#      web  tweet_count  tweet_length  tweet_rate  original_ratio
# 31     1       2534.0    112.831886    1.985893        0.459353  \
# 34     1        131.0    112.015267    0.334184        0.572519
# 62     1        116.0    123.551724    1.731343        0.301724
# 65     1          5.0    106.800000    0.050505        0.600000
# 78     1        374.0    111.580214    0.675090        0.414439
# 132    1         10.0    142.100000    5.000000        0.600000
#
#      retweeted_ratio  replied_to_ratio  quoted_ratio  retweet_count
# 31          0.146014          0.393844      0.000789         2643.0  \
# 34          0.404580          0.022901      0.000000          240.0
# 62          0.672414          0.025862      0.000000          727.0
# 65          0.400000          0.000000      0.000000            3.0
# 78          0.446524          0.069519      0.069519         2425.0
# 132         0.400000          0.000000      0.000000          107.0
#
#      retweet_ratio  ...  country_enc  city_enc  name_enc  stage_success
# 31        1.043015  ...           18       396       116              1  \
# 34        1.832061  ...            6       285       311              1
# 62        6.267241  ...           13       374       301              1
# 65        0.600000  ...           31       233       325              1
# 78        6.483957  ...            7       386       188              1
# 132      10.700000  ...            6       190       415              1
#
#      Predicted  Probability_0  Probability_1  Accuracy
# 31           1   2.963994e-01       0.703601  0.857143  \
# 34           1   4.184974e-01       0.581503  0.857143
# 62           1   3.286972e-02       0.967130  0.857143
# 65           1   4.689685e-01       0.531032  0.857143
# 78           1   4.476185e-01       0.552381  0.857143
# 132          1   3.100361e-09       1.000000  0.857143
#
#                                       Confusion_Matrix                   name
# 31   <function confusion_matrix at 0x0000019FD551F560>   CARSHARE VENTURES BV
# 34   <function confusion_matrix at 0x0000019FD551F560>         INDOORATLAS OY
# 62   <function confusion_matrix at 0x0000019FD551F560>  ILLUSIVE NETWORKS LTD
# 65   <function confusion_matrix at 0x0000019FD551F560>  ISOTROPIC SYSTEMS LTD
# 78   <function confusion_matrix at 0x0000019FD551F560>               EASYMILE
# 132  <function confusion_matrix at 0x0000019FD551F560>        NATURVENTION OY
#
# [6 rows x 26 columns]

# %% [markdown]
# Logistic - Carshare Ventures BV, Indooratlas OY, Illusive Networks LTD, Isotropic Systems LTD, Easy Mile, Naturvention OY

# %%
labels = ['Negative', 'Positive']
sns.heatmap(confusion_matrixlog
, annot=True, fmt='g', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.show()

# %% [markdown]
# We get a precision of 0.75 which isnt bad but we will try to do better.

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Random forest should not have scaling done

# %%
Y = df_filled['stage_success']
X = df_filled.select_dtypes(include='number').drop('stage_success', axis=1)

Train_X, Test_X, Train_Y, Test_Y = train_test_split(X, Y, train_size=0.8, test_size=0.2, random_state=100)



# Define the parameter grid with a range of values for each parameter
param_grid = {
    'max_depth': [1,2],
    'ccp_alpha': [0.5,1 ,1.5],
    'min_samples_split': [1, 2],
    'min_samples_leaf': [1, 2],
    'criterion': ['gini', 'entropy'],
    'class_weight': [None], # already tried others
    'max_features': [None], # already tested with others
    'max_leaf_nodes': [None, 1, 2],
    'min_impurity_decrease': [0.0, 0.1],
    'min_weight_fraction_leaf': [0.0, 0.1],
    'random_state': [None, 1,]

}

# Initialize the Decision Tree Classifier
dt_clf = DecisionTreeClassifier()

# Initialize the GridSearchCV with the parameter grid
grid_search = GridSearchCV(estimator=dt_clf, param_grid=param_grid, cv=10, n_jobs=-1, verbose=2)

# Fit the grid search to the data (assuming you have X_train and y_train)
grid_search.fit(Train_X, Train_Y)

# Print the best parameters found by the grid search
print("Best parameters found: ", grid_search.best_params_)
print("Best cross-validation score: ", grid_search.best_score_)
# Out:
# Fitting 10 folds for each of 1152 candidates, totalling 11520 fits
# Best parameters found:  {'ccp_alpha': 0.5, 'class_weight': None, 'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None}
# Best cross-validation score:  0.8446428571428571

# %%
dec_tree_clf = DecisionTreeClassifier(ccp_alpha=.5, class_weight=None, criterion='gini', max_depth=1, max_features=None, 
                                      max_leaf_nodes=None, min_impurity_decrease=0, min_samples_leaf=1, min_samples_split=2,
                                     min_weight_fraction_leaf=0, random_state=None)
dec_tree_clf.fit(Train_X, Train_Y)

y_pred = dec_tree_clf.predict(Test_X)

y_pred_prob = dec_tree_clf.predict_proba(Test_X)

dec_treeclf = metrics.confusion_matrix(Test_Y, y_pred, labels=dec_tree_clf.classes_)
display(dec_treeclf)
# Out:
# array([[116,   0],
#        [ 24,   0]], dtype=int64)

# %%
labels = ['Negative', 'Positive']
sns.heatmap(dec_treeclf, annot=True, fmt='g', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.show()

# %% [markdown]
# This is pretty bad and we will not take this into account. So instead we will try using random forest. Our model is performing really bad, as it is predicting that all of the companies will NOT succeed.

# %% [markdown]
# ## Random Forest

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# Define the parameter grid with a range of values for each parameter
param_grid = {
    'n_estimators': [50],                     # Number of trees in the forest
    'max_depth': [510],                    # Maximum depth of the tree
    'ccp_alpha': [0.0],                       # Complexity parameter for Minimal Cost-Complexity Pruning
    'min_samples_split': [2],               # Minimum number of samples required to split an internal node
    'min_samples_leaf': [ 3],                 # Minimum number of samples required to be at a leaf node
    'criterion': ['gini', 'entropy'],              # Function to measure the quality of a split
    'max_features': ['auto', 'log2'],              # The number of features to consider when looking for the best split
    'max_leaf_nodes': [None, 10],          # Maximum number of leaf nodes
    'min_impurity_decrease': [0.0],     # A node will be split if this split induces a decrease of the impurity greater than or equal to this value
    'min_weight_fraction_leaf': [0.0, 0.1],  # The minimum weighted fraction of the sum total of weights (of all the input samples) required to be at a leaf node
    'class_weight': [None],            # Weights associated with classes
    'random_state': [42]                           # Controls the randomness of the estimator
}

# Initialize the RandomForestClassifier
rf_model = RandomForestClassifier()

# Initialize the GridSearchCV with the parameter grid
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=2, n_jobs=-1, verbose=2)

# Fit the grid search to the data (assuming you have X_train and y_train)
grid_search.fit(Train_X, Train_Y)

# Print the best parameters found by the grid search
print("Best parameters found: ", grid_search.best_params_)
print("Best cross-validation score: ", grid_search.best_score_)
# Out:
# Fitting 2 folds for each of 16 candidates, totalling 32 fits
# Best parameters found:  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 510, 'max_features': 'auto', 'max_leaf_nodes': 10, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 3, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 50, 'random_state': 42}
# Best cross-validation score:  0.8571428571428572

# %%
from sklearn.ensemble import RandomForestClassifier

# Manually set parameters
params = {
    'ccp_alpha': 0,
    'class_weight': None,
    'criterion': 'gini',
    'max_depth': 510,
    'max_features': 'log2',
    'max_leaf_nodes': None,
    'min_impurity_decrease': 0.0,
    'min_samples_leaf': 3,
    'min_samples_split': 2,
    'min_weight_fraction_leaf': 0.0,
    'random_state': 42,
    'n_estimators': 50,  # Number of trees in the forest (not in the provided parameters)
}

# Create a RandomForestClassifier instance with the specified parameters
rf_model = RandomForestClassifier(**params)

# %%
rf_model.fit(Train_X, Train_Y)
y_pred = rf_model.predict(Test_X)
y_pred_prob = rf_model.predict_proba(Test_X)

# Calculate accuracy
accuracy = rf_model.score(Test_X, Test_Y)

# Calculate confusion matrix
confusion_matrixrf = metrics.confusion_matrix(Test_Y, y_pred)

# Convert predictions and probabilities to DataFrame
predictions_df = pd.DataFrame({
    'Predicted': y_pred,
    'Probability_0': y_pred_prob[:, 0],
    'Probability_1': y_pred_prob[:, 1]
}, index=Test_X.index)

# Convert Test_Y to a DataFrame
Test_Y_df = pd.DataFrame(Test_Y, index=Test_X.index, columns=['stage_success'])

# Convert Test_X to a DataFrame with original column names
Test_X_df = pd.DataFrame(Test_X, columns=Train_X.columns, index=Test_X.index)

# Merge predictions and actual values with the original test dataset
merged_test_data = pd.concat([Test_X_df, Test_Y_df, predictions_df], axis=1)

# Optionally, you can add accuracy and confusion matrix to the merged DataFrame
merged_test_data['Accuracy'] = accuracy
merged_test_data['Confusion_Matrix'] = str(confusion_matrix)

# Merge the 'name' column from df_filled into merged_test_data based on 'name_enc'
merged_test_data = merged_test_data.merge(df_filled[['name_enc', 'name']], on='name_enc', how='left')

# Display the ones we want
successes = merged_test_data[(merged_test_data['Predicted'] == 1) & (merged_test_data['stage_success'] == 1)]

display(successes)
# Out:
#      web  tweet_count  tweet_length  tweet_rate  original_ratio
# 1      1        406.0     94.135468    1.268750        0.184729  \
# 31     1       2534.0    112.831886    1.985893        0.459353
# 34     1        131.0    112.015267    0.334184        0.572519
# 62     1        116.0    123.551724    1.731343        0.301724
# 69     1         59.0    117.101695    0.246862        0.644068
# 78     1        374.0    111.580214    0.675090        0.414439
# 91     1        304.0    154.042763    0.564007        0.710526
# 121    1          5.0    122.600000    0.106383        0.400000
#
#      retweeted_ratio  replied_to_ratio  quoted_ratio  retweet_count
# 1           0.098522          0.716749      0.000000          319.0  \
# 31          0.146014          0.393844      0.000789         2643.0
# 34          0.404580          0.022901      0.000000          240.0
# 62          0.672414          0.025862      0.000000          727.0
# 69          0.237288          0.033898      0.084746          106.0
# 78          0.446524          0.069519      0.069519         2425.0
# 91          0.088816          0.095395      0.105263         1875.0
# 121         0.400000          0.200000      0.000000            6.0
#
#      retweet_ratio  ...  country_enc  city_enc  name_enc  stage_success
# 1         0.785714  ...           31       233       184              1  \
# 31        1.043015  ...           18       396       116              1
# 34        1.832061  ...            6       285       311              1
# 62        6.267241  ...           13       374       301              1
# 69        1.796610  ...           10        55        26              1
# 78        6.483957  ...            7       386       188              1
# 91        6.167763  ...           18        13       130              1
# 121       1.200000  ...           12        93       573              1
#
#      Predicted  Probability_0  Probability_1  Accuracy
# 1            1       0.358135       0.641865  0.878571  \
# 31           1       0.421477       0.578523  0.878571
# 34           1       0.345397       0.654603  0.878571
# 62           1       0.413381       0.586619  0.878571
# 69           1       0.351557       0.648443  0.878571
# 78           1       0.469032       0.530968  0.878571
# 91           1       0.489143       0.510857  0.878571
# 121          1       0.498821       0.501179  0.878571
#
#                                       Confusion_Matrix
# 1    <function confusion_matrix at 0x0000019FD551F560>  \
# 31   <function confusion_matrix at 0x0000019FD551F560>
# 34   <function confusion_matrix at 0x0000019FD551F560>
# 62   <function confusion_matrix at 0x0000019FD551F560>
# 69   <function confusion_matrix at 0x0000019FD551F560>
# 78   <function confusion_matrix at 0x0000019FD551F560>
# 91   <function confusion_matrix at 0x0000019FD551F560>
# 121  <function confusion_matrix at 0x0000019FD551F560>
#
#                                                   name
# 1                                       DUEDIL LIMITED
# 31                                CARSHARE VENTURES BV
# 34                                      INDOORATLAS OY
# 62                               ILLUSIVE NETWORKS LTD
# 69   AIMOTIVE INFORMATIKAI KORLATOLT FELELOSSEGU TA...
# 78                                            EASYMILE
# 91                                            CIWIT BV
# 121                                   SIRIUSXT LIMITED
#
# [8 rows x 26 columns]

# %% [markdown]
# Random Forest - Duedil Limited, Carshare Ventures BV, Indooratlas Oy, Illusive Networks LTD, Aimotive Informatikai Korlatolt felelossegu Ta, EasyMile, Ciwit BV, Siriusxt limited

# %%
labels = ['Negative', 'Positive']
sns.heatmap(confusion_matrixrf, annot=True, fmt='g', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.show()

# %% [markdown]
# Random Forest is the best model so far as the precision is 88.9%, which means that from the 9 companies that we are predicting that will succeed, only 1 will not. Which gives us a lot of confidence to trust our investment in this model. We will be choosing the 5 companies based on the results of this Random Forest model.

# %% [markdown]
# ## XGBOOST Classifier

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
from xgboost import XGBClassifier
classifier = XGBClassifier()
classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm) 
accuracy_score(y_test, y_pred)
# Out:
# [[120   4]
#  [ 14   2]]
# 0.8714285714285714

# %% [markdown]
# We do get a good accuracy but the recall is what is important and our precision is really bad where 33% of our positive predictions will end up being unsuccessful.

# %% [markdown]
# ## Neural Network

# %%
X = df_filled.select_dtypes(include='number').drop('stage_success', axis=1).to_numpy()
Y = df_filled['stage_success'].to_numpy(dtype = float ) 

from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Define the parameter grid
param_grid = {
    'hidden_layer_sizes': [ (20), (15), (12)], # i tried using more layers with higher neurons but in the end it made the accuracy lower. But the precision was higher... bc the problem we are solving doesnt really require higher precision i will aim to make the accuracy the highest.
    'activation': ['relu'],
    'solver': ['adam'],
    'alpha': [0.0001, 0.00001],
    'learning_rate': ['constant'],
    'max_iter': [200, 500],
    'learning_rate_init': [0.001],
    'momentum': [0.9],
    'early_stopping': [True, False],
    'validation_fraction': [0.3, 0.4]
}
# it took a long time to load so thats why you dont see a lot of options in easch parameter but I did test each one.

# Initialize the MLPClassifier
mlp = MLPClassifier(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=mlp, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Fit the grid search to the data
grid_search.fit(X_train_scaled, y_train)

# Print the best parameters found by the grid search
print("Best parameters found: ", grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# Best parameters found:  {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': 15, 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_iter': 500, 'momentum': 0.9, 'solver': 'adam', 'validation_fraction': 0.3}

# %%
# Train the final model with the best parameters
best_params = grid_search.best_params_
final_model = MLPClassifier(**best_params, random_state=42)
final_model.fit(X_train_scaled, y_train)

# Make predictions with the final model
y_pred = final_model.predict(X_test_scaled)

from sklearn.metrics import accuracy_score, classification_report

# Assuming y_train is your target variable for training data
baseline_accuracy = 1 - sum(y_train) / len(y_train)
print("Baseline Accuracy:", baseline_accuracy)

# Assuming y_test is your target variable for testing data and y_pred are the model predictions
model_accuracy = accuracy_score(y_test, y_pred)
print("Model Accuracy:", model_accuracy)

# Detailed classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Baseline Accuracy: 0.8357142857142857
# Model Accuracy: 0.8642857142857143
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.98      0.93       121
#          1.0       0.50      0.16      0.24        19
#
#     accuracy                           0.86       140
#    macro avg       0.69      0.57      0.58       140
# weighted avg       0.83      0.86      0.83       140

# %%
cm = metrics.confusion_matrix(y_test, y_pred, labels=final_model.classes_)
labels = ['Negative', 'Positive']
sns.heatmap(cm, annot=True, fmt='g', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.show()

print("accuracy",metrics.accuracy_score(y_test, y_pred))
# Precision
print("precision",metrics.precision_score(y_test, y_pred))
#Of all the instances the model identified as positive, how many were actually relevant?

# Recall
print("recall:", metrics.recall_score(y_test, y_pred))
#Of all the relevant instances in the dataset, how many did the model correctly identify?
# Out:
# accuracy 0.8642857142857143
# precision 0.5
# recall: 0.15789473684210525

# %% [markdown]
# The results here are also bad. Only a 50% precision which is not good.

# %% [markdown]
# ## Results
#
# In the end the random forest gave us the best result. with a precision of success of 88.9%. We will get the 5 companies from this one.
#
# #### Companies the model choses to be successful
# Logistic - Carshare Ventures BV, Indooratlas OY, Illusive Networks LTD, Isotropic Systems LTD, Easy Mile, Naturvention OY
# Decision Tree - 0
# Random Forest - Duedil Limited, Carshare Ventures BV, Indooratlas Oy, Illusive Networks LTD, Aimotive Informatikai Korlatolt felelossegu Ta, EasyMile, Ciwit BV, Siriusxt limited
# Neural Network - Velco, Thrustme, Ability Pharma SL, Industrial Phycology Limited, Aurelia Turbines Oy
#
# Repeated - Carshare Ventures BV, Easymile , Illusive Networks LTD
#
# High probability of being success from Random Forest model - Duedil Limited, Aimotive Informatikai Korlatolt felelossegu Ta, Indooratlas Oy
#
# ### Based on the model
# Here are the companies and the probability of success given by the model.
# We will invest in Carshare Ventures BV (0.70), Easymile(0.53) , Illusive Networks LTD(0.58), Duedil Limited(0.64), Indooratlas Oy(0.65)
#
# Venture Capital: Venture capital investments, which are higher risk, aim for even higher returns. Successful venture capitalists might expect returns of 30-50% per year, but these returns come with a high degree of risk and variability.
# Reference: NVCA on Venture Capital Returns
#
# **Carshare Ventures BV**:
# - Success Probability: 0.70
# - Investment: approx 1,130,000
#
# **Easymile**:
# - Success Probability: 0.53
# - Investment: approx 855,000
#
# **Illusive Networks LTD**:
# - Success Probability: 0.58
# - Investment: approx 935,000
#
# **Duedil Limited**:
# - Success Probability: 0.64
# - Investment: approx 1,030,000
#
# **Indooratlas Oy**:
# - Success Probability: 0.65
# - Investment: approx 1,050,000
#
# ### Final Investment Allocation:
#
# - **Carshare Ventures BV**: $1,130,000
# - **Easymile**: $855,000
# - **Illusive Networks LTD**: $935,000
# - **Duedil Limited**: $1,030,000
# - **Indooratlas Oy**: $1,050,000
#
# This allocation ensures that more funds are allocated to companies with higher success probabilities, while still diversifying the investment to mitigate risk.
#
# Carshare Ventures BV:
#
# Investment: $1,130,000
# Expected Return: $451,239
#
# Illusive Networks LTD:
#
# Investment: $935,000
# Expected Return: $374,067
#
# Duedil Limited:
#
# Investment: $1,030,000
# Expected Return: $412,125
#
# Indooratlas Oy:
#
# Investment: $1,050,000
# Expected Return: $420,568
#
# Easymile (Failure): we allow for this to fail based off 1/9 failure.
#
# Investment: $855,000
# Expected Return: $0
# Summary:
# Total Investment: $5,000,000
# Total Expected Return (with Easymile failing): $1,658,000 per year
#
# The chance of one of the companies failing that we choose is 1/9, so we assumed the worst above.
#
# If we were to have all businesses being a success, then our return would be the 40% return per year we desire and make 2,000,000.
